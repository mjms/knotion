# %%
# Knotion
# Ravelry + notion integration
# first part: yarn database

import requests
import json
import pandas as pd

# %%
config_path = "config.json"
with open(config_path, 'r') as configfile:
    config = json.load(configfile)

KNOTION_TOKEN = config['auth']['KNOTION_TOKEN']
DATABASE_ID = config['auth']['DATABASE_ID']
# headers = {
#     "Authorization": "Bearer " + KNOTION_TOKEN,
#     "Content-Type": "application/json",
#     "Notion-Version": "2022-06-28"
# }

# %%
def readDatabase(DATABASE_ID, headers):
    readURL = f'https://api.notion.com/v1/databases/{DATABASE_ID}'

    res = requests.request("GET", readURL, headers=headers)
    return res

res = readDatabase(DATABASE_ID, headers)

# %%
def readNotionDatabase(DATABASE_ID,KNOTION_TOKEN):
    readURL = f'https://api.notion.com/v1/databases/{DATABASE_ID}'
    headers = {
        "Authorization": "Bearer " + KNOTION_TOKEN,
        "Content-Type": "application/json",
        "Notion-Version": "2022-06-28"
    }
    return requests.request("GET", readURL, headers=headers)

class NotionDB:
    def __init__(self,DATABASE_ID,KNOTION_TOKEN):
        self.DATABASE_ID = DATABASE_ID
        self.KNOTION_TOKEN = KNOTION_TOKEN
        self.db = readNotionDatabase(DATABASE_ID,KNOTION_TOKEN)

    def check_knotion(self):
        # check if knotion db is already set up (has the correct properties)
        pass

    def setup_knotion(self):
        print(self.db)

# %%
notion = NotionDB(DATABASE_ID,KNOTION_TOKEN)
notion.db.json()
# Out:
# {'object': 'database',
#  'id': 'fbf11eb2-46d2-4d6a-89a7-53e48a0b2bcf',
#  'cover': None,
#  'icon': None,
#  'created_time': '2022-12-19T16:39:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '06f05932-1317-4d90-876e-6d958d141bf1'},
#  'last_edited_by': {'object': 'user',
#   'id': '06f05932-1317-4d90-876e-6d958d141bf1'},
#  'last_edited_time': '2022-12-19T21:47:00.000Z',
#  'title': [{'type': 'text',
#    'text': {'content': 'TEST_KNOTION', 'link': None},
#    'annotations': {'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'code': False,
#     'color': 'default'},
#    'plain_text': 'TEST_KNOTION',
#    'href': None}],
#  'description': [],
#  'is_inline': False,
#  'properties': {'Tags': {'id': 'o%5BcS',
#    'name': 'Tags',
#    'type': 'multi_select',
#    'multi_select': {'options': [{'id': '370882c6-1537-46df-9ed9-0bba76fa1bf2',
#       'name': 'Dk',
#       'color': 'brown'},
# ...

# %%
base_url = 'https://api.ravelry.com'

RAVELRY_BASIC_AUTH_USERNAME = config['auth']['RAVELRY_BASIC_AUTH_USERNAME']
RAVELRY_BASIC_AUTH_KEY = config['auth']['RAVELRY_BASIC_AUTH_KEY']
RAVELRY_USERNAME = config['auth']['RAVELRY_USERNAME']
r = requests.get(base_url+f'/projects/{RAVELRY_USERNAME}/list.json?include=collections', auth = (RAVELRY_BASIC_AUTH_USERNAME,RAVELRY_BASIC_AUTH_KEY))
r
# Out:
# <Response [200]>

# %%
print(json.dumps(r_json, indent=1))
# Out:
# {
#  "project": {
#   "comments_count": 0,
#   "completed": "2022/10/25",
#   "craft_id": 2,
#   "created_at": "2022/09/11 21:45:46 -0400",
#   "favorites_count": 0,
#   "id": 30820574,
#   "made_for": "",
#   "made_for_user_id": null,
#   "name": "Maid You Look Good",
#   "pattern_id": 1248968,
#   "permalink": "maid-you-look-dress",
#   "progress": 100,
#   "project_status_changed": "2022/10/25 19:17:38 -0400",
#   "project_status_id": 2,
#   "rating": 4,
#   "size": "",
#   "started": "2022/09/11",
#   "updated_at": "2022/10/25 19:22:31 -0400",
#   "user_id": 10546033,
#   "links": {
#    "self": {
#     "href": "https://www.ravelry.com/projects/mjmsmjm/maid-you-look-dress"
#    }
#   },
#   "personal_attributes": {
#    "favorited": false,
#    "bookmark_id": null
#   },
#   "pattern_name": "Maid You Look Dress",
#   "craft_name": "Knitting",
#   "status_name": "Finished",
#   "tag_names": [],
# ...

# %%
r_json = r.json()
df = pd.DataFrame(pd.json_normalize(r_json['projects']))
df.head()
# Out:
#    comments_count   completed  craft_id                 created_at  \
# 0               0  2022/10/25         2  2022/09/11 21:45:46 -0400
# 1               0  2022/09/22         2  2022/09/06 18:58:23 -0400
# 2               0  2022/09/11         2  2022/09/02 00:43:34 -0400
# 3               0  2022/08/27         2  2022/07/28 22:25:13 -0400
# 4               0  2022/08/07         2  2022/07/27 21:10:52 -0400
#
#    favorites_count        id made_for made_for_user_id  \
# 0                0  30820574                      None
# 1                0  30795153                      None
# 2                0  30767846                      None
# 3                1  30596763                      None
# 4                0  30592118                      None
#
#                                      name  pattern_id  ...  \
# 0                      Maid You Look Good   1248968.0  ...
# 1  Cozy Classic Raglan - Rainbow T-shirt!    988974.0  ...
# ...

# %%
pr = 0
PROJECT_ID = df.id[pr]
pr_r = requests.get(base_url+f'/projects/{RAVELRY_USERNAME}/{PROJECT_ID}.json', auth = (RAVELRY_BASIC_AUTH_USERNAME,RAVELRY_BASIC_AUTH_KEY))
pr_r
# Out:
# <Response [200]>

# %%
r_json = pr_r.json()
project_df = pd.DataFrame(pd.json_normalize(r_json))
project_df.head()
# Out:
#   comments  project.comments_count project.completed  project.craft_id  \
# 0       []                       0        2022/10/25                 2
#
#           project.created_at  project.favorites_count  project.id  \
# 0  2022/09/11 21:45:46 -0400                        0    30820574
#
#   project.made_for project.made_for_user_id        project.name  ...  \
# 0                                      None  Maid You Look Good  ...
#
#    project.private_notes_html project.private_notes  \
# 0                        None                  None
#
#                                       project.photos  \
# 0  [{'id': 116307918, 'sort_order': 1, 'x_offset'...
#
#                                        project.packs  project.user.id  \
# 0  [{'id': 109017226, 'primary_pack_id': None, 'p...         10546033
#
#    project.user.username                        project.user.tiny_photo_url  \
# 0                mjmsmjm  https://avatars-d.ravelrycache.com/mjmsmjm/883...
#
# ...

# %%
print(project_df['project.notes'].values)
# Out:
# ["Maid You Look Good\r\nA mash up of [Oshen Knits' Maid You Look Dress][1] \r\nand [AreUKnittingMe's Good Tank][2]\r\n\r\n\r\n  \r\n\r\n09-11-2022\n===================================\nwaist to underbust = 4.75in\n\n09-27-2022\n===================================\nfinished the Good Tank.\r\nLove the fit! The shadow wrap shaping is so cool and fits so well.\r\n\r\nI twisted some stitches and I don't know if it bothers me enough to fix it...\r\n\r\nPicking up the provisional cast on to start with the Maid You look dress (skirt section)\n\n10-07-2022\n===================================\nPut this down for awhile.\n\nStarted increases for the skirt section.\n\n10-09-2022\n===================================\nfinished the increases. \nI think my gauge is off now (looks looser than normal). Hopefully blocking will fix it.\n\n10-19-2022\n===================================\nsplit for the slit, knitting to midi length\n\n10-25-2022\n===================================\nturned hem:\n- stockin
# ...

# %%
project_df.columns
# Out:
# Index(['comments', 'project.comments_count', 'project.completed',
#        'project.craft_id', 'project.created_at', 'project.favorites_count',
#        'project.id', 'project.made_for', 'project.made_for_user_id',
#        'project.name', 'project.pattern_id', 'project.permalink',
#        'project.progress', 'project.project_status_changed',
#        'project.project_status_id', 'project.rating', 'project.size',
#        'project.started', 'project.updated_at', 'project.user_id',
#        'project.links.self.href', 'project.personal_attributes.favorited',
#        'project.personal_attributes.bookmark_id', 'project.pattern_name',
#        'project.craft_name', 'project.status_name', 'project.tag_names',
#        'project.notes_html', 'project.notes', 'project.needle_sizes',
#        'project.photos_count', 'project.ends_per_inch',
#        'project.picks_per_inch', 'project.gauge', 'project.row_gauge',
#        'project.gauge_repeats', 'project.gauge_divisor',
# ...

# %%
project_df['project.packs'].values
# Out:
# array([list([{'id': 109017226, 'primary_pack_id': None, 'project_id': 30820574, 'skeins': None, 'stash_id': None, 'total_grams': None, 'total_meters': None, 'total_ounces': None, 'total_yards': None, 'yarn_id': 215464, 'yarn_name': 'Lion Brand 24/7 Cotton DK', 'yarn_weight': {'crochet_gauge': None, 'id': 11, 'knit_gauge': '22', 'max_gauge': None, 'min_gauge': None, 'name': 'DK', 'ply': '8', 'wpi': '11'}, 'colorway': 'Cacao', 'shop_name': None, 'yarn': {'permalink': 'lion-brand-24-7-cotton-dk', 'id': 215464, 'name': '24/7 Cotton DK', 'yarn_company_name': 'Lion Brand', 'yarn_company_id': 99}, 'quantity_description': None, 'personal_name': None, 'dye_lot': '', 'color_family_id': None, 'grams_per_skein': 100, 'yards_per_skein': 273.0, 'meters_per_skein': 249.6, 'ounces_per_skein': 3.53, 'prefer_metric_weight': True, 'prefer_metric_length': False, 'shop_id': None, 'thread_size': None}])],
#       dtype=object)
